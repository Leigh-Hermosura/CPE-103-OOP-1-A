# %% [markdown]
# <a href="https://colab.research.google.com/github/Leigh-Hermosura/CPE-103-OOP-1-A/blob/main/Long_Quiz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calcu_grade():
  prelimHOA = float(input("\nPrelim Hands-on Activity (out of 100): "))
  prelimQuiz = float(input("Prelim Quiz (out of 100): "))
  prelimAss = float(input("Prelim Assignment (out of 100): "))
  prelimExam = float(input("Prelim Exam Grade (out of 100): "))
  prelimCS = (prelimHOA * 0.5) + (prelimQuiz * 0.3) + (prelimAss * 0.2)
  prelimGrade = (prelimExam * 0.5) + (prelimCS * 0.5)
  print("")

  midtermHOA = float(input("Midterm Hands-on Activity (out of 100): "))
  midtermQuiz = float(input("Midterm Quiz (out of 100): "))
  midtermAss = float(input("Midterm Assignment (out of 100): "))
  midtermExam = float(input("Midterm Exam Grade (out of 100): "))
  midtermCS = (midtermHOA * 0.5) + (midtermQuiz * 0.3) + (midtermAss * 0.2)
  midtermCombination = (midtermExam * 0.5) + (midtermCS * 0.5)
  midtermGrade = (prelimGrade * (1/3)) + (midtermCombination * (2/3))
  print(f"\nMidterm Grade is: {round(midtermGrade, 2)}")
  print("")

  finalHOA = float(input("Final Hands-on Activity (out of 100): "))
  finalQuiz = float(input("Final Quiz (out of 100): "))
  finalAss = float(input("Final Assignment (out of 100): "))
  finalExam = float(input("Final Exam Grade (out of 100): "))
  finalCS = (finalHOA * 0.5) + (finalQuiz * 0.3) + (finalAss * 0.2)
  finalCombination = (finalExam * 0.5) + (finalCS * 0.5)
  finalGrade = (midtermGrade * (1/3)) + (finalCombination * (2/3))
  print(f"\nFinal Grade is: {round(finalGrade, 2)}")

  if 99 <= finalGrade <= 100:
    finalGrade = "1.00"
  elif 96 <= finalGrade < 99:
    finalGrade = "1.25"
  elif 93 <= finalGrade < 96:
    finalGrade = "1.50"
  elif 90 <= finalGrade < 93:
    finalGrade = "1.75"
  elif 87 <= finalGrade < 90:
    finalGrade = "2.00"
  elif 84 <= finalGrade < 87:
    finalGrade = "2.25"
  elif 81 <= finalGrade < 84:
    finalGrade = "2.50"
  elif 78 <= finalGrade < 81:
    finalGrade = "2.75"
  elif 75 <= finalGrade < 78:
    finalGrade = "3.00"
  elif 72 <= finalGrade < 75:
    finalGrade = "4.00"
  elif finalGrade < 72:
    finalGrade = "5.00"

  print(f"Final grade in the course: {finalGrade}")

# %%
class Student():

  def __init__(self, id, name, program, sex, weight, height):
    self.id = id
    self.name = name
    self.program = program
    self.sex = sex
    self.weight = weight
    self.height = height

for i in range(3):
  print("-" * 50)
  choice = input("Enter Student (Ana, Mench, John): ")


  if choice.lower() == "ana":
    course = input("Enter Chosen Course: ")
    student = Student(id=20240001, name="Ana", program="BSEE", sex="Female", weight=48, height=150)
    print(f"\nStudent ID:            {student.id}")
    print(f"Student Name:          {student.name}")
    print(f"Student Program:       {student.program}")
    print(f"Student Sex:           {student.sex}")
    print(f"Student Weight:        {student.weight}kg")
    print(f"Student Height:        {student.height}cm")
    print("")
    calcu_grade()



  elif choice.lower() == "mench":
    course = input("Enter Chosen Course: ")
    student = Student(id=20240046, name="Mench", program="BSCPE", sex="Male", weight=69, height=179)
    print(f"\nStudent ID:            {student.id}")
    print(f"Student Name:          {student.name}")
    print(f"Student Program:       {student.program}")
    print(f"Student Sex:           {student.sex}")
    print(f"Student Weight:        {student.weight}kg")
    print(f"Student Height:        {student.height}cm")
    print("")
    calcu_grade()

  elif choice.lower() == "john":
    student = Student(id=20240018, name="John", program="BSECE", sex="Male", weight=55, height=152)
    print(f"\nStudent ID:            {student.id}")
    print(f"Student Name:          {student.name}")
    print(f"Student Program:       {student.program}")
    print(f"Student Sex:           {student.sex}")
    print(f"Student Weight:        {student.weight}kg")
    print(f"Student Height:        {student.height}cm")
    print("")
    calcu_grade()

  else:
    print("Wrong name input, please rerun the program")
# Out:
# --------------------------------------------------
# Enter Student (Ana, Mench, John): aNa
# Enter Chosen Course: CPE 103
#
# Student ID:            20240001
# Student Name:          Ana
# Student Program:       BSEE
# Student Sex:           Female
# Student Weight:        48kg
# Student Height:        150cm
#
#
# Prelim Hands-on Activity (out of 100): 65
# Prelim Quiz (out of 100): 87
# Prelim Assignment (out of 100): 75
# Prelim Exam Grade (out of 100): 88
#
# Midterm Hands-on Activity (out of 100): 75
# Midterm Quiz (out of 100): 45
# Midterm Assignment (out of 100): 87
# Midterm Exam Grade (out of 100): 99
#
# Midterm Grade is: 82.73
#
# Final Hands-on Activity (out of 100): 65
# Final Quiz (out of 100): 34
# Final Assignment (out of 100): 76
# Final Exam Grade (out of 100): 100
#
# Final Grade is: 80.21
# Final grade in the course: 2.75
# --------------------------------------------------
# Enter Student (Ana, Mench, John): MeNcH
# Enter Chosen Course: BES 000
#
# Student ID:            20240046
# Student Name:          Mench
# Student Program:       BSCPE
# Student Sex:           Male
# Student Weight:        69kg
# Student Height:        179cm
#
#
# Prelim Hands-on Activity (out of 100): 76
# Prelim Quiz (out of 100): 86
# Prelim Assignment (out of 100): 54
# Prelim Exam Grade (out of 100): 75
#
# Midterm Hands-on Activity (out of 100): 87
# Midterm Quiz (out of 100): 99
# Midterm Assignment (out of 100): 99
# Midterm Exam Grade (out of 100): 99
#
# Midterm Grade is: 88.93
#
# Final Hands-on Activity (out of 100): 86
# Final Quiz (out of 100): 98
# Final Assignment (out of 100): 89
# Final Exam Grade (out of 100): 100
#
# Final Grade is: 93.04
# Final grade in the course: 1.50
# --------------------------------------------------
# Enter Student (Ana, Mench, John): JOHN
#
# Student ID:            20240018
# Student Name:          John
# Student Program:       BSECE
# Student Sex:           Male
# Student Weight:        55kg
# Student Height:        152cm
#
#
# Prelim Hands-on Activity (out of 100): 45
# Prelim Quiz (out of 100): 67
# Prelim Assignment (out of 100): 65
# Prelim Exam Grade (out of 100): 88
#
# Midterm Hands-on Activity (out of 100): 98
# Midterm Quiz (out of 100): 67
# Midterm Assignment (out of 100): 87
# Midterm Exam Grade (out of 100): 98
#
# Midterm Grade is: 85.43
#
# Final Hands-on Activity (out of 100): 67
# Final Quiz (out of 100): 45
# Final Assignment (out of 100): 65
# Final Exam Grade (out of 100): 43
#
# Final Grade is: 62.81
# Final grade in the course: 5.00
